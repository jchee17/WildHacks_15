# %%
import pandas as pd
import statsmodels.api as sm
import pylab as pl
import numpy as np
from patsy import dmatrices

# read the data in
df = pd.read_csv('/home/jerry/GitHub/WildHacks_15/crashes1970-2015.csv')

# %%
# take a look
df.head()
# Out:
#                  Date   Time                            Location  \
# 0     August 29, 1970      ?                 Near Silchar, India
# 1     August 26, 1970      ?          Near Tam Ky, South Vietnam
# 2  September 02, 1970      ?  Near Dnepropetrovsk, Ukraine, USSR
# 3     August 30, 1970      ?           Haringvreter, Netherlands
# 4  September 03, 1970  21:26                Near Leningrad, USSR
#
#                     Operator Flight #  \
# 0            Indian Airlines        ?
# 1       Military - U.S. Army        ?
# 2                   Aeroflot        ?
# 3  Dutch Continental Airways        ?
# 4                   Aeroflot      W-4
#
#                                         Route  \
# 0                           Silchar - Gauhati
# 1                                           ?
# 2                                           ?
# 3                                           ?
# 4  Frunze, Kyrgyzstan - Leninabad, Tajikistan
#
# ...

# %%
#print sum(df['Operator'] == 'Aeroflot')
#print len(df['Operator'])
#print df.describe()
#df.Operator.value_counts().plot(kind='bar')

# %%
cols_to_keep = ['Date', 'Location', 'Operator', 'Route', 'AC Type', 'Aboard']
data = df[cols_to_keep]
data = data[data.Date != '?']
data = data[data.Location != '?']
data = data[data.Operator != '?']
data = data[data.Route != '?']
data = data[data['AC Type'] != '?']

# %%
data.head(50)
# Out:
#                   Date                                   Location  \
# 0      August 29, 1970                        Near Silchar, India
# 4   September 03, 1970                       Near Leningrad, USSR
# 5   September 02, 1970                           Lihovka, Ukraine
# 6   September 09, 1970                      Orocovis, Puerto Rico
# 7   September 08, 1970                         New York, New York
# 9   September 22, 1970                          Cranbrook, Canada
# 11   November 14, 1970             Near Huntington, West Virginia
# 12    October 10, 1970                       Fort Dix, New Jersey
# 13    October 16, 1970                       New Castle, Delaware
# 14    October 04, 1970                     Mahaffey, Pennsylvania
# 15    October 06, 1970               Near Germiston, South Africa
# 16    October 02, 1970                        Near Taipei, Taiwan
# 17    October 02, 1970  Mt. Trelease, near Silver Plume, Colorado
# ...
